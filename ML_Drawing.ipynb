# %% [markdown]
# # **Import Libraries**

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %% [markdown]
# #**Preprocess Image and Load**

# %%
# function for readina & Processing  image 
def load_image(img_path):
    img = tf.io.read_file(img_path)
    # how img being
    img = tf.image.decode_image(img, channels=3)
    # scaling img (data type)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_image('/IMG-20210130-WA0034.jpg')
style_image = load_image('/charles-etoroma-G3aJretwWps-unsplash.jpg')

# %% [markdown]
# # **Show img**

# %%
content_image.shape
# Out:
# TensorShape([1, 631, 841, 3])

# %%
plt.imshow(np.squeeze(content_image))
plt.show()

# %%
style_image.shape
# Out:
# TensorShape([1, 960, 960, 3])

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %% [markdown]
# #**Stylize Image**

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.show()
